# %%
import pandas as pd

# Load the data
column_names = ['ReviewID', 'CustomerID', 'ProductID', 'ReviewDate', 'Rating', 'ReviewText']
df = pd.read_csv(r'C:\Users\drewr\OneDrive\Escritorio\Google Cloud Training\Sentiment Analisis Python.csv', 
                 header=None, names=column_names, sep=';', quotechar='"', escapechar='\\', engine='python')

# Check for missing values
print("Missing values in each column:")
print(df.isnull().sum())

# Drop rows with missing ReviewText (if any)
df = df.dropna(subset=['ReviewText'])

# Convert ReviewDate to datetime (if needed)
df['ReviewDate'] = pd.to_datetime(df['ReviewDate'])

# Display the first few rows of the DataFrame
print("\nFirst 5 rows of the DataFrame:")
df.head()
# Out:
# Missing values in each column:
# ReviewID      0
# CustomerID    0
# ProductID     0
# ReviewDate    0
# Rating        0
# ReviewText    0
# dtype: int64
#
# First 5 rows of the DataFrame:
#    ReviewID  CustomerID  ProductID ReviewDate  Rating  \
# 0         1          77         18 2023-12-23       3
# 1         2          80         19 2024-12-25       5
# 2         3          50         13 2025-01-26       4
# 3         4          78         15 2025-04-21       3
# 4         5          64          2 2023-07-16       3
#
#                              ReviewText
# 0  Average experience, nothing special.
# 1            The quality is  top-notch.
# 2    Five stars for the quick delivery.
# 3   Good quality, but could be cheaper.
# 4  Average experience, nothing special.

# %%
# %pip install textblob
from textblob import TextBlob

# Function to get sentiment polarity
def get_sentiment(text):
    return TextBlob(text).sentiment.polarity

# Apply sentiment analysis to the ReviewText column
df['Sentiment'] = df['ReviewText'].apply(get_sentiment)

# Display the DataFrame with the new Sentiment column
print("\nDataFrame with Sentiment Analysis:")
df.head()
# Out:
# Requirement already satisfied: textblob in c:\users\drewr\anaconda3\lib\site-packages (0.19.0)
# Requirement already satisfied: nltk>=3.9 in c:\users\drewr\anaconda3\lib\site-packages (from textblob) (3.9.1)
# Requirement already satisfied: click in c:\users\drewr\anaconda3\lib\site-packages (from nltk>=3.9->textblob) (8.1.7)
# Requirement already satisfied: joblib in c:\users\drewr\anaconda3\lib\site-packages (from nltk>=3.9->textblob) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\drewr\anaconda3\lib\site-packages (from nltk>=3.9->textblob) (2024.9.11)
# Requirement already satisfied: tqdm in c:\users\drewr\anaconda3\lib\site-packages (from nltk>=3.9->textblob) (4.66.5)
# Requirement already satisfied: colorama in c:\users\drewr\anaconda3\lib\site-packages (from click->nltk>=3.9->textblob) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
#
# DataFrame with Sentiment Analysis:
#    ReviewID  CustomerID  ProductID ReviewDate  Rating  \
# 0         1          77         18 2023-12-23       3
# 1         2          80         19 2024-12-25       5
# 2         3          50         13 2025-01-26       4
# 3         4          78         15 2025-04-21       3
# 4         5          64          2 2023-07-16       3
#
#                              ReviewText  Sentiment
# 0  Average experience, nothing special.   0.103571
# 1            The quality is  top-notch.   1.000000
# 2    Five stars for the quick delivery.   0.333333
# 3   Good quality, but could be cheaper.   0.700000
# 4  Average experience, nothing special.   0.103571

# %%
def hybrid_sentiment_category(row):
    rating = row['Rating']
    sentiment = row['Sentiment']
    
    # Define rules based on rating and sentiment
    if rating >= 4:
        if sentiment >= 0.1:  # Strong alignment (high rating + positive sentiment)
            return 'Positive'
        elif sentiment <= -0.1:  # Conflict (high rating but negative sentiment)
            return 'Neutral (Check)'  # Flag for manual review
        else:  # Neutral sentiment
            return 'Positive (Weak)'  # Assume rating dominates
    
    elif rating <= 2:
        if sentiment <= -0.1:  # Strong alignment (low rating + negative sentiment)
            return 'Negative'
        elif sentiment >= 0.1:  # Conflict (low rating but positive sentiment)
            return 'Neutral (Check)'  # Flag for manual review
        else:  # Neutral sentiment
            return 'Negative (Weak)'  # Assume rating dominates
    
    else:  # Rating = 3 (neutral)
        if sentiment > 0.1:
            return 'Positive'
        elif sentiment < -0.1:
            return 'Negative'
        else:
            return 'Neutral'
        
    # Apply the hybrid categorization
df['HybridSentiment'] = df.apply(hybrid_sentiment_category, axis=1)

# Display results
print("\nDataFrame with Hybrid Sentiment Categories:")
print(df[['ReviewID', 'Rating', 'Sentiment', 'HybridSentiment']].head(10))

# Count sentiment categories
print("\nCount of Hybrid Sentiment Categories:")
print(df['HybridSentiment'].value_counts())
# Out:
# DataFrame with Hybrid Sentiment Categories:
#    ReviewID  Rating  Sentiment HybridSentiment
# 0         1       3   0.103571        Positive
# 1         2       5   1.000000        Positive
# 2         3       4   0.333333        Positive
# 3         4       3   0.700000        Positive
# 4         5       3   0.103571        Positive
# 5         6       4   0.200000        Positive
# 6         7       3   0.103571        Positive
# 7         8       5   1.000000        Positive
# 8         9       4   0.625000        Positive
# 9        10       5   0.600000        Positive
#
# Count of Hybrid Sentiment Categories:
# HybridSentiment
# Positive           1015
# Negative            200
# Negative (Weak)      51
# Positive (Weak)      49
# Neutral (Check)      48
# Name: count, dtype: int64

# %%
# Flag conflicting cases
conflict_mask = df['HybridSentiment'].str.contains('Check')
conflicting_reviews = df[conflict_mask][['ReviewID', 'ReviewText', 'Rating', 'Sentiment', 'HybridSentiment']]

print("\nConflicting Reviews (Manual Check Recommended):")
print(conflicting_reviews)
# Out:
# Conflicting Reviews (Manual Check Recommended):
#       ReviewID                                         ReviewText  Rating  \
# 57          58  The product  is okay, but the instructions wer...       2
# 61          62               Average experience, nothing special.       2
# 98          99               Average experience, nothing special.       2
# 105        106               Average experience, nothing special.       2
# 113        114               Average experience, nothing special.       2
# 120        121                Good quality, but could be cheaper.       2
# 127        128               Average experience, nothing special.       2
# 146        147               Average experience, nothing special.       2
# 147        148               Average experience, nothing special.       1
# 227        228  The product is okay, but the instructions were...       2
# 289        290               Average experience, nothing special.       2
# 353        354               Average experience, nothing special.       2
# 354        355               Average experience, nothing special.       2
# 372        373               Average experience, nothing special.       1
# 429        430               Average experience, nothing special.       2
# 491        492  The product is okay, but the instructions were...       2
# 505        506              Average experience,  nothing special.       2
# 513        514               Average experience, nothing special.       2
# 610        611               Average experience, nothing special.       2
# 637        638                Good quality, but could be cheaper.       2
# 660        661               Average experience, nothing special.       2
# 718        719  The product is okay, but the instructions were...       2
# 739        740                Good quality, but could be cheaper.       2
# 757        758              Average experience, nothing  special.       2
# 783        784  The product is okay, but the instructions were...       2
# 797        798               Average experience, nothing special.       2
# 829        830              Average experience, nothing  special.       2
# 833        834              Average  experience, nothing special.       2
# 848        849                Good quality, but could be cheaper.       2
# 877        878               Average experience, nothing special.       2
# 886        887               Average experience, nothing special.       2
# 896        897  The product is okay, but the instructions were...       2
# 946        947               Average experience, nothing special.       2
# 955        956               Average experience, nothing special.       2
# 979        980               Average experience, nothing special.       2
# 992        993                Good quality, but could be cheaper.       2
# 1008      1009  The product is okay, but the instructions were...       2
# 1067      1068  The product is okay, but the instructions were...       2
# 1096      1097               Average experience, nothing special.       2
# 1119      1120               Average experience, nothing special.       2
# 1124      1125                Good quality, but could be cheaper.       2
# 1170      1171               Average experience, nothing special.       2
# 1246      1247               Average experience, nothing special.       2
# 1275      1276               Good quality, but  could be cheaper.       2
# 1315      1316  The product is okay, but the instructions were...       2
# 1326      1327               Average experience, nothing special.       2
# 1340      1341              Average experience, nothing  special.       2
# 1359      1360              Average  experience, nothing special.       2
#
#       Sentiment  HybridSentiment
# 57     0.500000  Neutral (Check)
# 61     0.103571  Neutral (Check)
# 98     0.103571  Neutral (Check)
# 105    0.103571  Neutral (Check)
# 113    0.103571  Neutral (Check)
# 120    0.700000  Neutral (Check)
# 127    0.103571  Neutral (Check)
# 146    0.103571  Neutral (Check)
# 147    0.103571  Neutral (Check)
# 227    0.500000  Neutral (Check)
# 289    0.103571  Neutral (Check)
# 353    0.103571  Neutral (Check)
# 354    0.103571  Neutral (Check)
# 372    0.103571  Neutral (Check)
# 429    0.103571  Neutral (Check)
# 491    0.500000  Neutral (Check)
# 505    0.103571  Neutral (Check)
# 513    0.103571  Neutral (Check)
# 610    0.103571  Neutral (Check)
# 637    0.700000  Neutral (Check)
# 660    0.103571  Neutral (Check)
# 718    0.500000  Neutral (Check)
# 739    0.700000  Neutral (Check)
# 757    0.103571  Neutral (Check)
# 783    0.500000  Neutral (Check)
# 797    0.103571  Neutral (Check)
# 829    0.103571  Neutral (Check)
# 833    0.103571  Neutral (Check)
# 848    0.700000  Neutral (Check)
# 877    0.103571  Neutral (Check)
# 886    0.103571  Neutral (Check)
# 896    0.500000  Neutral (Check)
# 946    0.103571  Neutral (Check)
# 955    0.103571  Neutral (Check)
# 979    0.103571  Neutral (Check)
# 992    0.700000  Neutral (Check)
# 1008   0.500000  Neutral (Check)
# 1067   0.500000  Neutral (Check)
# 1096   0.103571  Neutral (Check)
# 1119   0.103571  Neutral (Check)
# 1124   0.700000  Neutral (Check)
# 1170   0.103571  Neutral (Check)
# 1246   0.103571  Neutral (Check)
# 1275   0.700000  Neutral (Check)
# 1315   0.500000  Neutral (Check)
# 1326   0.103571  Neutral (Check)
# 1340   0.103571  Neutral (Check)
# 1359   0.103571  Neutral (Check)

# %%
import pandas as pd
from textblob import TextBlob

# Load the data
column_names = ['ReviewID', 'CustomerID', 'ProductID', 'ReviewDate', 'Rating', 'ReviewText']
df = pd.read_csv(r'C:\Users\drewr\OneDrive\Escritorio\Google Cloud Training\Sentiment Analisis Python.csv', 
                 header=None, names=column_names, sep=';', quotechar='"', escapechar='\\', engine='python')

# Check for missing values
print("Missing values in each column:")
print(df.isnull().sum())

# Drop rows with missing ReviewText
df = df.dropna(subset=['ReviewText'])

# Convert ReviewDate to datetime
df['ReviewDate'] = pd.to_datetime(df['ReviewDate'])

# Function to get sentiment polarity
def get_sentiment(text):
    return TextBlob(text).sentiment.polarity

# Add sentiment polarity column
df['Sentiment'] = df['ReviewText'].apply(get_sentiment)

# Hybrid sentiment categorization function
def hybrid_sentiment_category(row):
    rating = row['Rating']
    sentiment = row['Sentiment']
    
    if rating >= 4:
        if sentiment >= 0.1:
            return 'Positive'
        elif sentiment <= -0.1:
            return 'Neutral (Check)'
        else:
            return 'Positive (Weak)'
    elif rating <= 2:
        if sentiment <= -0.1:
            return 'Negative'
        elif sentiment >= 0.1:
            return 'Neutral (Check)'
        else:
            return 'Negative (Weak)'
    else:  # Rating = 3
        if sentiment > 0.1:
            return 'Positive'
        elif sentiment < -0.1:
            return 'Negative'
        else:
            return 'Neutral'

# Apply hybrid categorization
df['HybridSentiment'] = df.apply(hybrid_sentiment_category, axis=1)

# Function to create sentiment buckets
def categorize_sentiment_bucket(hybrid_sentiment):
    if 'Check' in hybrid_sentiment:
        return 'Conflict - Requires Review'
    elif 'Weak' in hybrid_sentiment:
        if 'Positive' in hybrid_sentiment:
            return 'Rating-Driven Positive'
        elif 'Negative' in hybrid_sentiment:
            return 'Rating-Driven Negative'
    else:
        return f'Aligned {hybrid_sentiment}'

# Create sentiment bucket column
df['SentimentBucket'] = df['HybridSentiment'].apply(categorize_sentiment_bucket)

# Display the updated DataFrame
print("\nUpdated DataFrame with Sentiment Buckets:")
df.head(30)
# Out:
# Missing values in each column:
# ReviewID      0
# CustomerID    0
# ProductID     0
# ReviewDate    0
# Rating        0
# ReviewText    0
# dtype: int64
#
# Updated DataFrame with Sentiment Buckets:
#     ReviewID  CustomerID  ProductID ReviewDate  Rating  \
# 0          1          77         18 2023-12-23       3
# 1          2          80         19 2024-12-25       5
# 2          3          50         13 2025-01-26       4
# 3          4          78         15 2025-04-21       3
# 4          5          64          2 2023-07-16       3
# 5          6          81          1 2025-12-21       4
# 6          7          16          1 2024-01-29       3
# 7          8          55          8 2024-08-15       5
# 8          9           3         13 2023-09-01       4
# 9         10          78          6 2024-06-17       5
# 10        11          54          9 2023-07-17       4
# 11        12          77          2 2025-01-13       2
# 12        13          93          6 2024-08-20       5
# 13        14          23          2 2025-06-16       4
# 14        15          29         11 2023-01-27       5
# 15        16          95         17 2023-01-06       5
# 16        17          88          4 2025-10-29       3
# 17        18          17         16 2024-11-23       4
# 18        19          34         13 2024-01-04       4
# 19        20          34          6 2023-04-29       1
# 20        21          22         15 2023-04-08       5
# 21        22          52          3 2025-10-30       4
# 22        23          69         18 2023-07-02       5
# 23        24         100          4 2025-07-18       3
# 24        25          55         20 2024-12-19       4
# 25        26          76         11 2024-08-21       4
# 26        27          56          6 2025-11-24       4
# 27        28          76          8 2025-05-27       5
# 28        29          38         13 2023-05-31       4
# 29        30          84          6 2024-03-18       4
#
#                                            ReviewText  Sentiment  \
# 0                Average experience, nothing special.   0.103571
# 1                          The quality is  top-notch.   1.000000
# 2                  Five stars for the quick delivery.   0.333333
# 3                 Good quality, but could be cheaper.   0.700000
# 4                Average experience, nothing special.   0.103571
# 5                  Customer support was very helpful.   0.200000
# 6                Average experience, nothing special.   0.103571
# 7                          The quality  is top-notch.   1.000000
# 8                I love this product, will buy again!   0.625000
# 9                Excellent product, highly recommend!   0.600000
# 10                    Great purchase, very satisfied.   0.725000
# 11             Product did  not meet my expectations.   0.000000
# 12                    Great purchase, very satisfied.   0.725000
# 13                Good quality, but could be cheaper.   0.700000
# 14                    Great purchase, very satisfied.   0.725000
# 15               Excellent product, highly recommend!   0.600000
# 16                               Not worth the money.  -0.150000
# 17  Shipping was fast and the item was well-packaged.   0.200000
# 18                          The quality is top-notch.   1.000000
# 19          I had a bad experience with this product.  -0.700000
# 20                       Amazing value for the price.   0.600000
# 21                          The quality is top-notch.   1.000000
# 22                 Five stars for the quick delivery.   0.333333
# 23              I love this  product, will buy again!   0.625000
# 24  Shipping was fast and the item was well-packaged.   0.200000
# 25                 Five stars for the quick delivery.   0.333333
# 26                          The quality is top-notch.   1.000000
# 27                 Five stars for the quick delivery.   0.333333
# 28               I love this product, will buy again!   0.625000
# 29                 Five stars for the quick delivery.   0.333333
#
#     HybridSentiment         SentimentBucket
# 0          Positive        Aligned Positive
# 1          Positive        Aligned Positive
# 2          Positive        Aligned Positive
# 3          Positive        Aligned Positive
# 4          Positive        Aligned Positive
# 5          Positive        Aligned Positive
# 6          Positive        Aligned Positive
# 7          Positive        Aligned Positive
# 8          Positive        Aligned Positive
# 9          Positive        Aligned Positive
# 10         Positive        Aligned Positive
# 11  Negative (Weak)  Rating-Driven Negative
# 12         Positive        Aligned Positive
# 13         Positive        Aligned Positive
# 14         Positive        Aligned Positive
# 15         Positive        Aligned Positive
# 16         Negative        Aligned Negative
# 17         Positive        Aligned Positive
# 18         Positive        Aligned Positive
# 19         Negative        Aligned Negative
# 20         Positive        Aligned Positive
# 21         Positive        Aligned Positive
# 22         Positive        Aligned Positive
# 23         Positive        Aligned Positive
# 24         Positive        Aligned Positive
# 25         Positive        Aligned Positive
# 26         Positive        Aligned Positive
# 27         Positive        Aligned Positive
# 28         Positive        Aligned Positive
# 29         Positive        Aligned Positive

# %%
# Save the updated DataFrame to a CSV file
output_path = r'C:\Users\drewr\OneDrive\Escritorio\Google Cloud Training\Sentiment_Analysis_Results_With_Insights1.csv'
df.to_csv(output_path, index=False)
print(f"\nUpdated DataFrame saved to: {output_path}")
# Out:
# Updated DataFrame saved to: C:\Users\drewr\OneDrive\Escritorio\Google Cloud Training\Sentiment_Analysis_Results_With_Insights1.csv
